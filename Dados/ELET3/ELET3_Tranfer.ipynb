# %%
import tensorflow as tf
import os
import random
import numpy as np

## 1. Criação de uma SEED

SEED = 0

def criar_seed(seed=SEED):
  os.environ['PYTHONHASHSEED'] = str(seed) # Controla aleatoriedade interna do interpretador Python
  random.seed(seed) # Controla aleatoriedade da biblioteca random
  np.random.seed(seed) # Controla aleatoriedade do NumPy
  tf.random.set_seed(seed) # Controla aleatoriedade do TensorFlow (pesos, embaralhamento, etc)

def setar_deterministico(seed=SEED): # Garantir que se obtenha os mesmos valores ao rodar o código novamente
  criar_seed(seed=seed) # Setar as seeds
  os.environ['TF_DETERMINISTIC_OPS'] = '1' # Força o TensorFlow a usar operações determinísticas
  os.environ['TF_CUDNN_DETERMINISTIC'] = '1' # Força operações determinísticas específicas da GPU (cuDNN)
  tf.config.threading.set_inter_op_parallelism_threads(1) # Limita o paralelismo entre operações a 1 thread
  tf.config.threading.set_intra_op_parallelism_threads(1) # Limita o paralelismo dentro de cada operação a 1 thread

setar_deterministico(SEED)  # Executa tudo acima com a seed escolhida

# %%
## Bibliotecas

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from keras.models import load_model
from keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, r2_score

import joblib

# %%
## Carregando Informações da PETR3

acao = 'ELET3'

modelo_base = load_model('Modelo_VALE3.keras')
modelo_base.compile(optimizer='adam', loss='mse')

X_train = np.load(f'X_train_{acao}.npy')
y_train = np.load(f'y_train_{acao}.npy')
X_test = np.load(f'X_test_{acao}.npy')
y_test = np.load(f'y_test_{acao}.npy')
y_real = np.load(f'y_real_{acao}.npy')
scaler = joblib.load(f'scaler_{acao}.pkl')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 12 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
## Aplicação do Transfer Learning + Treinamento

modelo_transferido = modelo_base

modelo_transferido.fit(
    X_train, y_train,
    epochs=65,
    batch_size=40,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 4.4280e-04 - val_loss: 1.6581e-04
# Epoch 2/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.6378e-04 - val_loss: 1.8023e-04
# Epoch 3/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 3.7125e-04 - val_loss: 1.8315e-04
# Epoch 4/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.6656e-04 - val_loss: 1.8070e-04
# Epoch 5/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 3.6236e-04 - val_loss: 1.7886e-04
# Epoch 6/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5902e-04 - val_loss: 1.7764e-04
# Epoch 7/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5627e-04 - val_loss: 1.7681e-04
# Epoch 8/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5396e-04 - val_loss: 1.7623e-04
# Epoch 9/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.5198e-04 - val_loss: 1.7580e-04
# Epoch 10/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5026e-04 - val_loss: 1.7549e-04
# Epoch 11/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4873e-04 - val_loss: 1.7524e-04
# Epoch 12/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.4737e-04 - val_loss: 1.7504e-04
# Epoch 13/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.4614e-04 - val_loss: 1.7488e-04
# Epoch 14/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 3.4503e-04 - val_loss: 1.7474e-04
# Epoch 15/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4401e-04 - val_loss: 1.7462e-04
# Epoch 16/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4308e-04 - val_loss: 1.7451e-04
# Epoch 17/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4222e-04 - val_loss: 1.7441e-04
# Epoch 18/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4142e-04 - val_loss: 1.7431e-04
# Epoch 19/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4066e-04 - val_loss: 1.7422e-04
# Epoch 20/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3995e-04 - val_loss: 1.7412e-04
# Epoch 21/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.3928e-04 - val_loss: 1.7403e-04
# Epoch 22/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3863e-04 - val_loss: 1.7393e-04
# Epoch 23/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.3802e-04 - val_loss: 1.7383e-04
# Epoch 24/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 3.3742e-04 - val_loss: 1.7374e-04
# Epoch 25/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.3684e-04 - val_loss: 1.7364e-04
# Epoch 26/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3628e-04 - val_loss: 1.7354e-04
# Epoch 27/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.3573e-04 - val_loss: 1.7343e-04
# Epoch 28/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3519e-04 - val_loss: 1.7333e-04
# Epoch 29/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3467e-04 - val_loss: 1.7323e-04
# Epoch 30/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3415e-04 - val_loss: 1.7312e-04
# Epoch 31/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.3363e-04 - val_loss: 1.7302e-04
# Epoch 32/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3313e-04 - val_loss: 1.7291e-04
# Epoch 33/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 3.3263e-04 - val_loss: 1.7280e-04
# Epoch 34/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 3.3213e-04 - val_loss: 1.7269e-04
# Epoch 35/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.3164e-04 - val_loss: 1.7258e-04
# Epoch 36/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3115e-04 - val_loss: 1.7247e-04
# Epoch 37/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3066e-04 - val_loss: 1.7235e-04
# Epoch 38/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3018e-04 - val_loss: 1.7223e-04
# Epoch 39/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.2970e-04 - val_loss: 1.7210e-04
# Epoch 40/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2922e-04 - val_loss: 1.7197e-04
# Epoch 41/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.2874e-04 - val_loss: 1.7184e-04
# Epoch 42/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2827e-04 - val_loss: 1.7171e-04
# Epoch 43/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.2780e-04 - val_loss: 1.7158e-04
# Epoch 44/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 3.2733e-04 - val_loss: 1.7145e-04
# Epoch 45/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.2688e-04 - val_loss: 1.7132e-04
# Epoch 46/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2643e-04 - val_loss: 1.7119e-04
# Epoch 47/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2598e-04 - val_loss: 1.7107e-04
# Epoch 48/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.2555e-04 - val_loss: 1.7095e-04
# Epoch 49/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2513e-04 - val_loss: 1.7083e-04
# Epoch 50/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.2471e-04 - val_loss: 1.7072e-04
# Epoch 51/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.2431e-04 - val_loss: 1.7061e-04
# Epoch 52/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.2391e-04 - val_loss: 1.7051e-04
# Epoch 53/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 3.2352e-04 - val_loss: 1.7041e-04
# Epoch 54/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2314e-04 - val_loss: 1.7032e-04
# Epoch 55/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2276e-04 - val_loss: 1.7024e-04
# Epoch 56/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.2239e-04 - val_loss: 1.7015e-04
# Epoch 57/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2203e-04 - val_loss: 1.7008e-04
# Epoch 58/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2166e-04 - val_loss: 1.7001e-04
# Epoch 59/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.2131e-04 - val_loss: 1.6995e-04
# Epoch 60/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2095e-04 - val_loss: 1.6990e-04
# Epoch 61/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.2060e-04 - val_loss: 1.6986e-04
# Epoch 62/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 3.2024e-04 - val_loss: 1.6983e-04
# Epoch 63/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 3.1990e-04 - val_loss: 1.6981e-04
# Epoch 64/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.1955e-04 - val_loss: 1.6981e-04
# Epoch 65/65
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.1921e-04 - val_loss: 1.6981e-04

# %%
## Predição e Desnormalização

y_pred = modelo_transferido.predict(X_test)

y_pred_real = scaler.inverse_transform(np.concatenate([y_pred, np.zeros((len(y_pred), scaler.n_features_in_ - 1))], axis=1))[:, 0]
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step

# %%
## Métricas

print("MAE:", mean_absolute_error(y_real, y_pred_real))
print("MAPE:", mean_absolute_percentage_error(y_real, y_pred_real))
print("R²:", r2_score(y_real, y_pred_real))
# Out:
# MAE: 0.4455582890234343
# MAPE: 0.0120572927535256
# R²: 0.962074856370831

# %%
## Gráfico

plt.figure(figsize=(10, 6))
sns.set_style('whitegrid')
plt.plot(y_real, label='Preço Real')
plt.plot(y_pred_real, label='Preço Previsto')
plt.xlabel('Dias Previstos')
plt.ylabel(f'Preço de Fechamento {acao}')
plt.title(f'Previsão do Fechamento da {acao}', fontweight='bold', fontsize=16)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.set_style('whitegrid')

erro = y_real.flatten() - y_pred_real.flatten()  # Garante que são vetores 1D

plt.plot(erro, label='Erro (Real - Previsto)', color='purple')
plt.axhline(0, color='black', linestyle='--')

plt.title(f'Erro de Previsão - {acao}', fontsize=14)
plt.xlabel('Dias')
plt.ylabel('Erro em R$')
plt.legend()
plt.show()

# %%
modelo_transferido.save('Modelo_ELET3.keras', save_format='keras')
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras

# %%
modelo_transferido.save('Modelo_ELET3.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
